# %% [markdown]
# # Cleaning Data: Python Data Playbook
#
# [Cleaning Data: Python Data Playbook](https://app.pluralsight.com/library/courses/cleaning-data-python-data-playbook)
# Cleaning the dataset is an essential part of any data project, but it can be challenging. This course will teach you the basics of cleaning datasets with pandas, and will teach you techniques that you can apply immediately in real world projects.
#
# ## Author
# [Chris Achard](https://app.pluralsight.com/profile/author/chris-achard)
#
# ## Learning Plataform
# [Pluralsight](https://www.pluralsight.com/)
#
# ## Description
# At the core of any successful project that involves a real world dataset is a thorough knowledge of how to clean that dataset from missing, bad, or inaccurate data. In this course, Cleaning Data: Python Data Playbook, you'll learn how to use pandas to clean a real world dataset. First, you'll learn how to understand, view, and explore the data you have. Next, you'll explore how to access just the data that you want to keep in your dataset. Finally, you'll discover different ways to handle bad and missing data. When you're finished with this course, you'll have a foundational knowledge of cleaning real world datasets with pandas that will help you as you move forward to working on real world data science or machine learning problems.

# %%
import pandas as pd
import wget
from os.path import exists
import re
from numpy import nan

# %%
if not exists('data/artwork_data.csv'):
    wget.download('https://raw.githubusercontent.com/vsvale/datasets/main/artwork_data.csv','data')

# %%
art = pd.read_csv('data/artwork_data.csv',error_bad_lines=False)
# Out:
# /tmp/ipykernel_1545/1242547657.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   art = pd.read_csv('data/artwork_data.csv',error_bad_lines=False)
# /tmp/ipykernel_1545/1242547657.py:1: DtypeWarning: Columns (9,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   art = pd.read_csv('data/artwork_data.csv',error_bad_lines=False)

# %%
art.width = pd.to_numeric(art.width,errors='coerce')
art.height = pd.to_numeric(art.height,errors='coerce')
art.year = pd.to_numeric(art.year,errors='coerce')

# %%
art.head()
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 1  1036           A00002   Blake, Robert     artist        38
# 2  1037           A00003   Blake, Robert     artist        38
# 3  1038           A00004   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 1  Two Drawings of Frightened Figures, Probably f...          date not known
# 2  The Preaching of Warning. Verso: An Old Man En...                 ?c.1785
# 3     Six Drawings of Figures with Outstretched Arms          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
# 2        Graphite on paper. Verso: graphite on paper
# 3                                  Graphite on paper
# 4                            Line engraving on paper
#
#                                           creditLine    year  acquisitionYear  \
# 0                Presented by Mrs John Richmond 1922     NaN           1922.0
# 1                Presented by Mrs John Richmond 1922     NaN           1922.0
# 2                Presented by Mrs John Richmond 1922  1785.0           1922.0
# 3                Presented by Mrs John Richmond 1922     NaN           1922.0
# 4  Purchased with the assistance of a special gra...  1826.0           1919.0
#
#               dimensions  width  height  depth units inscription  \
# 0  support: 394 x 419 mm  394.0   419.0    NaN    mm         NaN
# 1  support: 311 x 213 mm  311.0   213.0    NaN    mm         NaN
# 2  support: 343 x 467 mm  343.0   467.0    NaN    mm         NaN
# 3  support: 318 x 394 mm  318.0   394.0    NaN    mm         NaN
# 4    image: 243 x 335 mm  243.0   335.0    NaN    mm         NaN
#
#   thumbnailCopyright                                       thumbnailUrl  \
# 0                NaN  http://www.tate.org.uk/art/images/work/A/A00/A...
# 1                NaN  http://www.tate.org.uk/art/images/work/A/A00/A...
# 2                NaN  http://www.tate.org.uk/art/images/work/A/A00/A...
# 3                NaN  http://www.tate.org.uk/art/images/work/A/A00/A...
# 4                NaN  http://www.tate.org.uk/art/images/work/A/A00/A...
#
#                                                  url
# 0  http://www.tate.org.uk/art/artworks/blake-a-fi...
# 1  http://www.tate.org.uk/art/artworks/blake-two-...
# 2  http://www.tate.org.uk/art/artworks/blake-the-...
# 3  http://www.tate.org.uk/art/artworks/blake-six-...
# 4  http://www.tate.org.uk/art/artworks/blake-the-...

# %%
art.dtypes
# Out:
# id                      int64
# accession_number       object
# artist                 object
# artistRole             object
# artistId                int64
# title                  object
# dateText               object
# medium                 object
# creditLine             object
# year                  float64
# acquisitionYear       float64
# dimensions             object
# width                 float64
# height                float64
# depth                 float64
# units                  object
# inscription            object
# thumbnailCopyright     object
# thumbnailUrl           object
# url                    object
# dtype: object

# %%
art.describe()
# Out:
#                   id      artistId          year  acquisitionYear  \
# count   69201.000000  69201.000000  63804.000000     69156.000000
# mean    39148.026213   1201.063251   1867.227823      1910.646856
# std     25980.468687   2019.422535     72.012718        64.202148
# min         3.000000      0.000000   1545.000000      1823.000000
# 25%     19096.000000    558.000000   1817.000000      1856.000000
# 50%     37339.000000    558.000000   1831.000000      1856.000000
# 75%     54712.000000   1137.000000   1953.000000      1982.000000
# max    129068.000000  19232.000000   2012.000000      2013.000000
#
#               width        height         depth
# count  65834.000000  65859.000000   2514.000000
# mean     323.472435    346.436173    479.197772
# std      408.810182    538.037975   1051.141734
# min        3.000000      6.000000      1.000000
# 25%      118.000000    117.000000     48.250000
# 50%      175.000000    190.000000    190.000000
# 75%      345.000000    359.000000    450.000000
# max    11960.000000  37500.000000  18290.000000

# %%
art.year
# Out:
# 0           NaN
# 1           NaN
# 2        1785.0
# 3           NaN
# 4        1826.0
#           ...
# 69196    1975.0
# 69197    1976.0
# 69198    1996.0
# 69199    2000.0
# 69200    1764.0
# Name: year, Length: 69201, dtype: float64

# %%
art.year.min()
# Out:
# 1545.0

# %%
art.year.max()
# Out:
# 2012.0

# %%
art.year.agg(['mean','std'])
# Out:
# mean    1867.227823
# std       72.012718
# Name: year, dtype: float64

# %%
art.year.count()
# Out:
# 63804

# %%
art.year.groupby(art.year).count()
# Out:
# year
# 1545.0      2
# 1557.0      1
# 1563.0      1
# 1565.0      1
# 1569.0      1
#          ...
# 2008.0    111
# 2009.0     84
# 2010.0     64
# 2011.0     29
# 2012.0     46
# Name: year, Length: 360, dtype: int64

# %%
normalize = (art.height - art.height.mean()) / art.height.std()
normalize
# Out:
# 0        0.134867
# 1       -0.248005
# 2        0.224081
# 3        0.088402
# 4       -0.021255
#            ...
# 69196   -0.077013
# 69197   -0.077013
# 69198    3.835350
# 69199         NaN
# 69200    0.582791
# Name: height, Length: 69201, dtype: float64

# %%
minmax = (art.height - art.height.min()) / (art.height.max() - art.height.min())
minmax
# Out:
# 0        0.011015
# 1        0.005521
# 2        0.012295
# 3        0.010348
# 4        0.008775
#            ...
# 69196    0.007975
# 69197    0.007975
# 69198    0.064117
# 69199         NaN
# 69200    0.017443
# Name: height, Length: 69201, dtype: float64

# %%
art['height_norm'] = normalize
art['height_minmax'] = minmax

# %%
art['height_cm'] = art.height.transform(lambda x: x/10)

# %%
art.groupby('artist')['height'].transform('mean')
# Out:
# 0         373.250000
# 1         373.250000
# 2         373.250000
# 3         373.250000
# 4         266.944134
#             ...
# 69196     305.000000
# 69197     305.000000
# 69198    1491.285714
# 69199    3515.333333
# 69200     660.000000
# Name: height, Length: 69201, dtype: float64

# %%
simpleart= art.filter(items=['artist','height','width'])
simpleart
# Out:
#                    artist  height  width
# 0           Blake, Robert   419.0  394.0
# 1           Blake, Robert   213.0  311.0
# 2           Blake, Robert   467.0  343.0
# 3           Blake, Robert   394.0  318.0
# 4          Blake, William   335.0  243.0
# ...                   ...     ...    ...
# 69196  P-Orridge, Genesis   305.0  305.0
# 69197  P-Orridge, Genesis   305.0  305.0
# 69198        Hatoum, Mona  2410.0   45.0
# 69199       Creed, Martin     NaN    NaN
# 69200   Brunias, Agostino   660.0  508.0
#
# [69201 rows x 3 columns]

# %%
simpleart.drop(0)
# Out:
#                    artist  height  width
# 1           Blake, Robert   213.0  311.0
# 2           Blake, Robert   467.0  343.0
# 3           Blake, Robert   394.0  318.0
# 4          Blake, William   335.0  243.0
# 5          Blake, William   338.0  240.0
# ...                   ...     ...    ...
# 69196  P-Orridge, Genesis   305.0  305.0
# 69197  P-Orridge, Genesis   305.0  305.0
# 69198        Hatoum, Mona  2410.0   45.0
# 69199       Creed, Martin     NaN    NaN
# 69200   Brunias, Agostino   660.0  508.0
#
# [69200 rows x 3 columns]

# %%
simpleart['columtodrop'] = 0
simpleart['columntodrop'] = 1
simpleart
# Out:
#                    artist  height  width  columtodrop  columntodrop
# 0           Blake, Robert   419.0  394.0            0             1
# 1           Blake, Robert   213.0  311.0            0             1
# 2           Blake, Robert   467.0  343.0            0             1
# 3           Blake, Robert   394.0  318.0            0             1
# 4          Blake, William   335.0  243.0            0             1
# ...                   ...     ...    ...          ...           ...
# 69196  P-Orridge, Genesis   305.0  305.0            0             1
# 69197  P-Orridge, Genesis   305.0  305.0            0             1
# 69198        Hatoum, Mona  2410.0   45.0            0             1
# 69199       Creed, Martin     NaN    NaN            0             1
# 69200   Brunias, Agostino   660.0  508.0            0             1
#
# [69201 rows x 5 columns]

# %%
simpleart.drop('columtodrop',axis=1,inplace=True)
simpleart.drop(columns=['columntodrop'],inplace=True)
simpleart
# Out:
#                    artist  height  width
# 0           Blake, Robert   419.0  394.0
# 1           Blake, Robert   213.0  311.0
# 2           Blake, Robert   467.0  343.0
# 3           Blake, Robert   394.0  318.0
# 4          Blake, William   335.0  243.0
# ...                   ...     ...    ...
# 69196  P-Orridge, Genesis   305.0  305.0
# 69197  P-Orridge, Genesis   305.0  305.0
# 69198        Hatoum, Mona  2410.0   45.0
# 69199       Creed, Martin     NaN    NaN
# 69200   Brunias, Agostino   660.0  508.0
#
# [69201 rows x 3 columns]

# %%
art.columns
# Out:
# Index(['id', 'accession_number', 'artist', 'artistRole', 'artistId', 'title',
#        'dateText', 'medium', 'creditLine', 'year', 'acquisitionYear',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnailCopyright', 'thumbnailUrl', 'url', 'height_norm',
#        'height_minmax', 'height_cm'],
#       dtype='object')

# %%
art.columns = [re.sub(r'([A-Z])',r'_\1' ,x).lower() for x in art.columns]
art.columns
# Out:
# Index(['id', 'accession_number', 'artist', 'artist_role', 'artist_id', 'title',
#        'date_text', 'medium', 'credit_line', 'year', 'acquisition_year',
#        'dimensions', 'width', 'height', 'depth', 'units', 'inscription',
#        'thumbnail_copyright', 'thumbnail_url', 'url', 'height_norm',
#        'height_minmax', 'height_cm'],
#       dtype='object')

# %%
art.rename(columns={'thumbnail_url':'thumbnail'},inplace=True)

# %%
art['artist'][0]
# Out:
# 'Blake, Robert'

# %%
art[['artist','medium']]['artist'][0]
# Out:
# 'Blake, Robert'

# %%
art[['artist','medium']][1:2]
# Out:
#           artist             medium
# 1  Blake, Robert  Graphite on paper

# %%
art[art['year'] > 2000][['artist','medium','year']]
# Out:
#                      artist  \
# 1763       Richter, Gerhard
# 1765       Richter, Gerhard
# 1766       Richter, Gerhard
# 1767       Richter, Gerhard
# 1770             Mueck, Ron
# ...                     ...
# 69178        Walker, Kelley
# 69179       Bulloch, Angela
# 69183          Black, Karla
# 69187          Lord, Andrew
# 69190  Andrade, Jonathas de
#
#                                                   medium    year
# 1763                                      Glass and wood  2004.0
# 1765                                 Oil paint on canvas  2004.0
# 1766                              Oil paint on aluminium  2002.0
# 1767                              Oil paint on aluminium  2002.0
# 1770                                         Mixed media  2005.0
# ...                                                  ...     ...
# 69178                       2 screenprints on fibreboard  2010.0
# 69179  4 aluminium pixel boxes with DMX control box, ...  2012.0
# 69183  Cellophane, paint, sellotape, plaster powder, ...  2011.0
# 69187                          Ceramic, silver and epoxy  2004.0
# 69190  151 text panels, typewritten ink on paper, 53 ...  2009.0
#
# [1484 rows x 3 columns]

# %%
art.loc[art.artist == 'Richter, Gerhard',['title','year']]
# Out:
#                                                    title    year
# 1759                       Mirror Painting (Grey, 735-2)  1991.0
# 1760            Corner Mirror, brown-blue (737-1, 737-2)  1991.0
# 1761         Corner Mirror, green-red (737-2 A, 737-2 B)  1991.0
# 1762                                        48 Portraits  1971.0
# 1763                                            11 Panes  2004.0
# 1764                           Abstract Painting (809-3)  1994.0
# 1765                    Abstract Painting (Skin) (887-3)  2004.0
# 1766                Abstract Painting (Silicate) (880-4)  2002.0
# 1767                    Abstract Painting (Grey) (880-3)  2002.0
# 1919      Self Portrait Standing, Three Times, 17.3.1991  1991.0
# 1920                Two Sculptures for a Room by Palermo  1971.0
# 2081                                   Brigid Polk (305)  1971.0
# 2082                      Gilbert, George (381-1, 381-2)  1975.0
# 2083                                            Untitled  1985.0
# 52724                                        Elizabeth I  1966.0
# 55403  128 Details from a Picture (Halifax 1978) II (...  1998.0
# 57790                          Abstract Painting No. 439  1978.0
# 57822                              Oil Sketch No. 432/11  1977.0
# 60634                                            St John  1988.0
# 61939                Self-Portrait, Three Times, 24.1.90  1990.0
# 62024                            Abstract Painting (726)  1990.0

# %%
art.medium
# Out:
# 0        Watercolour, ink, chalk and graphite on paper....
# 1                                        Graphite on paper
# 2              Graphite on paper. Verso: graphite on paper
# 3                                        Graphite on paper
# 4                                  Line engraving on paper
#                                ...
# 69196     Perspex, Wood, hairpiece, tampon and human blood
# 69197    Wood, Perspex, plastic, photograph on paper, t...
# 69198                                 Soap and glass beads
# 69199                                     Gallery lighting
# 69200                                  Oil paint on canvas
# Name: medium, Length: 69201, dtype: object

# %%
art.loc[art.medium.str.contains('Graphite',case=False,na=False),['artist','medium']]
# Out:
#                        artist  \
# 0               Blake, Robert
# 1               Blake, Robert
# 2               Blake, Robert
# 3               Blake, Robert
# 32             Blake, William
# ...                       ...
# 69140           Horn, Rebecca
# 69154  Hepworth, Dame Barbara
# 69155  Hepworth, Dame Barbara
# 69156  Hepworth, Dame Barbara
# 69157  Hepworth, Dame Barbara
#
#                                                   medium
# 0      Watercolour, ink, chalk and graphite on paper....
# 1                                      Graphite on paper
# 2            Graphite on paper. Verso: graphite on paper
# 3                                      Graphite on paper
# 32           Graphite on paper. Verso: graphite on paper
# ...                                                  ...
# 69140  Graphite, coloured graphite and acrylic paint ...
# 69154  Graphite, watercolour, crayon and oil paint on...
# 69155  Oil paint, watercolour, crayon and graphite on...
# 69156  Oil paint, watercolour, crayon and graphite on...
# 69157                    Oil paint and graphite on paper
#
# [32313 rows x 2 columns]

# %%
art.loc[art.medium.str.contains('(?i)Graphite',regex=True,na=False),['artist','medium']]
# Out:
#                        artist  \
# 0               Blake, Robert
# 1               Blake, Robert
# 2               Blake, Robert
# 3               Blake, Robert
# 32             Blake, William
# ...                       ...
# 69140           Horn, Rebecca
# 69154  Hepworth, Dame Barbara
# 69155  Hepworth, Dame Barbara
# 69156  Hepworth, Dame Barbara
# 69157  Hepworth, Dame Barbara
#
#                                                   medium
# 0      Watercolour, ink, chalk and graphite on paper....
# 1                                      Graphite on paper
# 2            Graphite on paper. Verso: graphite on paper
# 3                                      Graphite on paper
# 32           Graphite on paper. Verso: graphite on paper
# ...                                                  ...
# 69140  Graphite, coloured graphite and acrylic paint ...
# 69154  Graphite, watercolour, crayon and oil paint on...
# 69155  Oil paint, watercolour, crayon and graphite on...
# 69156  Oil paint, watercolour, crayon and graphite on...
# 69157                    Oil paint and graphite on paper
#
# [32313 rows x 2 columns]

# %%
art.loc[
        art.medium.str.contains('Graphite|line',case=False,na=False) &
        art.artist.str.contains('(?i)Blake',regex=True,na=False) &
        art.year.astype('str').str.contains('1797',case=False,na=False),
        ['artist','medium','year']
        ]
# Out:
#                artist                               medium    year
# 62011  Blake, William  Line engraving and etching on paper  1797.0
# 62012  Blake, William  Line engraving and etching on paper  1797.0
# 62013  Blake, William  Line engraving and etching on paper  1797.0

# %%
art.loc[art.title.str.contains('\s$',regex=True)]
# Out:
#           id accession_number                artist artist_role  artist_id  \
# 49498   4308           P07466  Hamilton Finlay, Ian      artist       1093
# 50534   2235           P11065         Clarke, Brian      artist        911
# 50535   2236           P11066         Clarke, Brian      artist        911
# 50537   2238           P11068         Clarke, Brian      artist        911
# 53186  21168           P77679     Bourgeois, Louise      artist       2351
# 56283   5826           T00705     Hamilton, Richard      artist       1244
# 67409  88191           T12064          Leach, David      artist       7651
# 67432  88215           T12087        Leach, Bernard      artist       1478
#
#                                                    title date_text  \
# 49498  Port-Distinguishing Letters of Scottish Fishin...      1976
# 50534                                              Boys       1981
# 50535                                         Buildings       1981
# 50537                                  Pray for Josquin       1981
# 53186                            Untitled (Safety Pins)       1991
# 56283  Towards a definitive statement on the coming t...      1962
# 67409                        2 Standard Ware Mead Cups     1945–55
# 67432                                             Bowl      c.1960
#
#                                                   medium  \
# 49498                        Screenprint on ceramic tile
# 50534                               Screenprint on paper
# 50535                               Screenprint on paper
# 50537                               Screenprint on paper
# 53186                                  Drypoint on paper
# 56283  Oil paint, cellulose paint and printed paper o...
# 67409                                   Ochre porcelain
# 67432                                          Porcelain
#
#                                              credit_line    year  ...  height  \
# 49498                                     Purchased 1981  1976.0  ...   153.0
# 50534                     Presented by Paul Beldock 1983  1981.0  ...   700.0
# 50535                     Presented by Paul Beldock 1983  1981.0  ...   698.0
# 50537                     Presented by Paul Beldock 1983  1981.0  ...   688.0
# 53186                                     Purchased 1994  1991.0  ...   379.0
# 56283                                     Purchased 1964  1962.0  ...   813.0
# 67409  Accepted by HM Government in lieu of inheritan...  1945.0  ...    80.0
# 67432  Accepted by HM Government in lieu of inheritan...  1960.0  ...   140.0
#
#        depth  units     inscription  \
# 49498    NaN     mm             NaN
# 50534    NaN     mm  date inscribed
# 50535    NaN     mm  date inscribed
# 50537    NaN     mm  date inscribed
# 53186    NaN     mm             NaN
# 56283    NaN     mm  date inscribed
# 67409   80.0     mm             NaN
# 67432  140.0     mm             NaN
#
#                                    thumbnail_copyright  \
# 49498                  © Estate of Ian Hamilton Finlay
# 50534  © Brian Clarke. All Rights Reserved 2014 / DACS
# 50535  © Brian Clarke. All Rights Reserved 2014 / DACS
# 50537  © Brian Clarke. All Rights Reserved 2014 / DACS
# 53186                          © The Easton Foundation
# 56283                 © The estate of Richard Hamilton
# 67409                    © The estate of Bernard Leach
# 67432                    © The estate of Bernard Leach
#
#                                                thumbnail  \
# 49498  http://www.tate.org.uk/art/images/work/P/P07/P...
# 50534  http://www.tate.org.uk/art/images/work/P/P11/P...
# 50535  http://www.tate.org.uk/art/images/work/P/P11/P...
# 50537  http://www.tate.org.uk/art/images/work/P/P11/P...
# 53186  http://www.tate.org.uk/art/images/work/P/P77/P...
# 56283  http://www.tate.org.uk/art/images/work/T/T00/T...
# 67409  http://www.tate.org.uk/art/images/work/T/T12/T...
# 67432  http://www.tate.org.uk/art/images/work/T/T12/T...
#
#                                                      url height_norm  \
# 49498  http://www.tate.org.uk/art/artworks/hamilton-f...   -0.359521
# 50534  http://www.tate.org.uk/art/artworks/clarke-boy...    0.657135
# 50535  http://www.tate.org.uk/art/artworks/clarke-bui...    0.653418
# 50537  http://www.tate.org.uk/art/artworks/clarke-pra...    0.634832
# 53186  http://www.tate.org.uk/art/artworks/bourgeois-...    0.060523
# 56283  http://www.tate.org.uk/art/artworks/hamilton-t...    0.867158
# 67409  http://www.tate.org.uk/art/artworks/leach-2-st...   -0.495200
# 67432  http://www.tate.org.uk/art/artworks/leach-bowl...   -0.383683
#
#       height_minmax height_cm
# 49498      0.003921      15.3
# 50534      0.018510      70.0
# 50535      0.018456      69.8
# 50537      0.018190      68.8
# 53186      0.009948      37.9
# 56283      0.021523      81.3
# 67409      0.001974       8.0
# 67432      0.003574      14.0
#
# [8 rows x 23 columns]

# %%
art.title = art.title.str.strip()

# %%
pd.isna(art.loc[:,'date_text'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 69196    False
# 69197    False
# 69198    False
# 69199    False
# 69200    False
# Name: date_text, Length: 69201, dtype: bool

# %%
art.replace({'date_text':{'date not known': nan}},inplace=True)

# %%
art.loc[art.date_text=='date not known',['date_text']] = nan

# %%
art.loc[art.year.notnull() & art.year.astype(str).str.contains('^[0-9]')]
# Out:
#            id accession_number              artist artist_role  artist_id  \
# 2        1037           A00003       Blake, Robert      artist         38
# 4        1039           A00005      Blake, William      artist         39
# 5        1040           A00006      Blake, William      artist         39
# 6        1041           A00007      Blake, William      artist         39
# 7        1042           A00008      Blake, William      artist         39
# ...       ...              ...                 ...         ...        ...
# 69196  122960           T13865  P-Orridge, Genesis      artist      16646
# 69197  122961           T13866  P-Orridge, Genesis      artist      16646
# 69198  121181           T13867        Hatoum, Mona      artist       2365
# 69199  112306           T13868       Creed, Martin      artist       2760
# 69200  127035           T13869   Brunias, Agostino      artist       3824
#
#                                                    title  \
# 2      The Preaching of Warning. Verso: An Old Man En...
# 4      The Circle of the Lustful: Francesca da Rimini...
# 5          Ciampolo the Barrator Tormented by the Devils
# 6                            The Baffled Devils Fighting
# 7      The Six-Footed Serpent Attacking Agnolo Brunel...
# ...                                                  ...
# 69196                        Larvae (from Tampax Romana)
# 69197                   Living Womb (from Tampax Romana)
# 69198                                      Present Tense
# 69199          Work No. 227: The lights going on and off
# 69200                   Dancing Scene in the West Indies
#
#                     date_text  \
# 2                     ?c.1785
# 4      1826–7, reprinted 1892
# 5      1826–7, reprinted 1892
# 6      1826–7, reprinted 1892
# 7      1826–7, reprinted 1892
# ...                       ...
# 69196                    1975
# 69197                    1976
# 69198                    1996
# 69199                    2000
# 69200                 1764–96
#
#                                                   medium  \
# 2            Graphite on paper. Verso: graphite on paper
# 4                                Line engraving on paper
# 5                                Line engraving on paper
# 6                                Line engraving on paper
# 7                                Line engraving on paper
# ...                                                  ...
# 69196   Perspex, Wood, hairpiece, tampon and human blood
# 69197  Wood, Perspex, plastic, photograph on paper, t...
# 69198                               Soap and glass beads
# 69199                                   Gallery lighting
# 69200                                Oil paint on canvas
#
#                                              credit_line    year  ...  height  \
# 2                    Presented by Mrs John Richmond 1922  1785.0  ...   467.0
# 4      Purchased with the assistance of a special gra...  1826.0  ...   335.0
# 5      Purchased with the assistance of a special gra...  1826.0  ...   338.0
# 6      Purchased with the assistance of a special gra...  1826.0  ...   334.0
# 7      Purchased with the assistance of a special gra...  1826.0  ...   340.0
# ...                                                  ...     ...  ...     ...
# 69196                 Transferred from Tate Archive 2012  1975.0  ...   305.0
# 69197                 Transferred from Tate Archive 2012  1976.0  ...   305.0
# 69198                     Presented by Tate Members 2013  1996.0  ...  2410.0
# 69199  Purchased with funds provided by Tate Members,...  2000.0  ...     NaN
# 69200  Purchased with assistance from Tate Patrons an...  1764.0  ...   660.0
#
#         depth  units  inscription  thumbnail_copyright  \
# 2         NaN     mm          NaN                  NaN
# 4         NaN     mm          NaN                  NaN
# 5         NaN     mm          NaN                  NaN
# 6         NaN     mm          NaN                  NaN
# 7         NaN     mm          NaN                  NaN
# ...       ...    ...          ...                  ...
# 69196   135.0     mm          NaN                  NaN
# 69197   135.0     mm          NaN                  NaN
# 69198  2990.0     mm          NaN                  NaN
# 69199     NaN    NaN          NaN                  NaN
# 69200     NaN     mm          NaN                  NaN
#
#                                                thumbnail  \
# 2      http://www.tate.org.uk/art/images/work/A/A00/A...
# 4      http://www.tate.org.uk/art/images/work/A/A00/A...
# 5      http://www.tate.org.uk/art/images/work/A/A00/A...
# 6      http://www.tate.org.uk/art/images/work/A/A00/A...
# 7      http://www.tate.org.uk/art/images/work/A/A00/A...
# ...                                                  ...
# 69196                                                NaN
# 69197                                                NaN
# 69198                                                NaN
# 69199                                                NaN
# 69200  http://www.tate.org.uk/art/images/work/T/T13/T...
#
#                                                      url height_norm  \
# 2      http://www.tate.org.uk/art/artworks/blake-the-...    0.224081
# 4      http://www.tate.org.uk/art/artworks/blake-the-...   -0.021255
# 5      http://www.tate.org.uk/art/artworks/blake-ciam...   -0.015680
# 6      http://www.tate.org.uk/art/artworks/blake-the-...   -0.023114
# 7      http://www.tate.org.uk/art/artworks/blake-the-...   -0.011962
# ...                                                  ...         ...
# 69196  http://www.tate.org.uk/art/artworks/p-orridge-...   -0.077013
# 69197  http://www.tate.org.uk/art/artworks/p-orridge-...   -0.077013
# 69198  http://www.tate.org.uk/art/artworks/hatoum-pre...    3.835350
# 69199  http://www.tate.org.uk/art/artworks/creed-work...         NaN
# 69200  http://www.tate.org.uk/art/artworks/brunias-da...    0.582791
#
#       height_minmax height_cm
# 2          0.012295      46.7
# 4          0.008775      33.5
# 5          0.008855      33.8
# 6          0.008748      33.4
# 7          0.008908      34.0
# ...             ...       ...
# 69196      0.007975      30.5
# 69197      0.007975      30.5
# 69198      0.064117     241.0
# 69199           NaN       NaN
# 69200      0.017443      66.0
#
# [63804 rows x 23 columns]

# %%
art.loc[art.year=='no date',['year']] = nan

# %%
art.fillna(value={'depth':0},inplace=True)

# %%
art.dropna()
# Out:
#           id accession_number             artist artist_role  artist_id  \
# 1025     550           A01029  Ardizzone, Edward      artist        659
# 1026     551           A01030  Ardizzone, Edward      artist        659
# 1027     552           A01031  Ardizzone, Edward      artist        659
# 1028     553           A01032  Ardizzone, Edward      artist        659
# 1029     554           A01033  Ardizzone, Edward      artist        659
# ...      ...              ...                ...         ...        ...
# 67576  89914           T12231       Moon, Jeremy      artist       1656
# 67577  89915           T12232       Moon, Jeremy      artist       1656
# 67578  89916           T12233       Moon, Jeremy      artist       1656
# 67579  89917           T12234       Moon, Jeremy      artist       1656
# 67580  89918           T12235       Moon, Jeremy      artist       1656
#
#                     title date_text                        medium  \
# 1025     At the Brasserie      1931  Watercolour and ink on paper
# 1026          The Meeting      1931  Watercolour and ink on paper
# 1027          The Arrival      1931  Watercolour and ink on paper
# 1028          The Bedroom      1931  Watercolour and ink on paper
# 1029        The Departure      1931  Watercolour and ink on paper
# ...                   ...       ...                           ...
# 67576   Drawing [18/7/71]      1971  Graphite and pastel on paper
# 67577  Drawing [13/12/71]      1971  Graphite and pastel on paper
# 67578   Drawing [25/5/73]      1973  Graphite and pastel on paper
# 67579   Drawing [24/6/74]      1973  Graphite and pastel on paper
# 67580   Drawing [19/2/73]      1973  Graphite and pastel on paper
#
#                                          credit_line    year  ...  height  \
# 1025                                  Purchased 1940  1931.0  ...   222.0
# 1026                                  Purchased 1940  1931.0  ...   159.0
# 1027                                  Purchased 1940  1931.0  ...   184.0
# 1028                                  Purchased 1940  1931.0  ...   229.0
# 1029                                  Purchased 1940  1931.0  ...   210.0
# ...                                              ...     ...  ...     ...
# 67576                                 Purchased 2006  1971.0  ...   253.0
# 67577                                 Purchased 2006  1971.0  ...   253.0
# 67578  Purchased with assistance from Anne Best 2006  1973.0  ...   253.0
# 67579                                 Purchased 2006  1973.0  ...   253.0
# 67580                                 Purchased 2006  1973.0  ...   253.0
#
#       depth  units     inscription      thumbnail_copyright  \
# 1025    0.0     mm  date inscribed                   © Tate
# 1026    0.0     mm  date inscribed                   © Tate
# 1027    0.0     mm  date inscribed                   © Tate
# 1028    0.0     mm  date inscribed                   © Tate
# 1029    0.0     mm  date inscribed                   © Tate
# ...     ...    ...             ...                      ...
# 67576   0.0     mm  date inscribed  © Estate of Jeremy Moon
# 67577   0.0     mm  date inscribed  © Estate of Jeremy Moon
# 67578   0.0     mm  date inscribed  © Estate of Jeremy Moon
# 67579   0.0     mm  date inscribed  © Estate of Jeremy Moon
# 67580   0.0     mm  date inscribed  © Estate of Jeremy Moon
#
#                                                thumbnail  \
# 1025   http://www.tate.org.uk/art/images/work/A/A01/A...
# 1026   http://www.tate.org.uk/art/images/work/A/A01/A...
# 1027   http://www.tate.org.uk/art/images/work/A/A01/A...
# 1028   http://www.tate.org.uk/art/images/work/A/A01/A...
# 1029   http://www.tate.org.uk/art/images/work/A/A01/A...
# ...                                                  ...
# 67576  http://www.tate.org.uk/art/images/work/T/T12/T...
# 67577  http://www.tate.org.uk/art/images/work/T/T12/T...
# 67578  http://www.tate.org.uk/art/images/work/T/T12/T...
# 67579  http://www.tate.org.uk/art/images/work/T/T12/T...
# 67580  http://www.tate.org.uk/art/images/work/T/T12/T...
#
#                                                      url height_norm  \
# 1025   http://www.tate.org.uk/art/artworks/ardizzone-...   -0.231278
# 1026   http://www.tate.org.uk/art/artworks/ardizzone-...   -0.348370
# 1027   http://www.tate.org.uk/art/artworks/ardizzone-...   -0.301905
# 1028   http://www.tate.org.uk/art/artworks/ardizzone-...   -0.218267
# 1029   http://www.tate.org.uk/art/artworks/ardizzone-...   -0.253581
# ...                                                  ...         ...
# 67576  http://www.tate.org.uk/art/artworks/moon-drawi...   -0.173661
# 67577  http://www.tate.org.uk/art/artworks/moon-drawi...   -0.173661
# 67578  http://www.tate.org.uk/art/artworks/moon-drawi...   -0.173661
# 67579  http://www.tate.org.uk/art/artworks/moon-drawi...   -0.173661
# 67580  http://www.tate.org.uk/art/artworks/moon-drawi...   -0.173661
#
#       height_minmax height_cm
# 1025       0.005761      22.2
# 1026       0.004081      15.9
# 1027       0.004747      18.4
# 1028       0.005948      22.9
# 1029       0.005441      21.0
# ...             ...       ...
# 67576      0.006588      25.3
# 67577      0.006588      25.3
# 67578      0.006588      25.3
# 67579      0.006588      25.3
# 67580      0.006588      25.3
#
# [3839 rows x 23 columns]

# %%
art.dropna(subset=['year','acquisition_year'],how='all',inplace=True)

# %%
art.drop_duplicates(inplace=True)
